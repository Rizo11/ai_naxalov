# %% [markdown]
# <a href="https://colab.research.google.com/github/Rizo11/ai_naxalov/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Type conversions**
#
# 1. explicit
# 2. implicit
#
#
# in any language, including python, 2 different types can't be added

# %%
a = 10
b = 20/2

print (a + b)
# Out:
# 20.0

# %%
x = 5
type(x)
# Out:
# int

# %% [markdown]
# in the above test we see that results is 20.0 which is a first converted to float and then added to float b.

# %%
import math
a = 1.125
print(a - int(a))


print(1000*(a - int(a)))

a = 1.17
print(1000*(a - int(a)))

print(1000*math.ceil((a - int(a))))
print(math.ceil((a - int(a))))
# Out:
# 0.125
# 125.0
# 169.99999999999994
# 1000
# 1

# %% [markdown]
# ### Floating point precision problem

# %% [markdown]
# #**Functions**

# %%
a = 5
x = 3

def main():
  x = 5
  return 0

print(x)
# Out:
# 3

# %% [markdown]
# ### Build-in functions

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(abs(-69))
# Out:
# 69

# %%
a = 1.17
a = a - 1
a *= 100
print(round(a))
print(round(-2.5))
# Out:
# 17
# -2

# %% [markdown]
# ## round()

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# **n digits is the number of number after comma**
#   - by defaults n is optional abd n = 0

# %%
print(round(1.2, 0))
# Out:
# 1.0

# %% [markdown]
# ## pow()

# %%
print(pow(12, 2))
# Out:
# 144

# %% [markdown]
# ## input()

# %%
age = int(input("How old are you:"))
print(age)
# Out:
# How old are you:12
# 12

# %% [markdown]
# ## eval()

# %%
expression = "2 + 3 * 4"
result = eval(expression)
print(result)  # prints 14
# Out:
# 14

# %% [markdown]
# ## practice

# %%
def negate(a):
  return 0 - abs(a)


def nearestSQRT(a):
  a = pow(a, 0.5)
  a = round(a)
  return pow(a, 2)

# %%
print(nearestSQRT(15))
# Out:
# 16

# %% [markdown]
# # Mathematical functions

# %%
from math import *

print(sqrt(9))
# Out:
# 3.0

# %% [markdown]
# * round
# * ceil
# * trunc
# * floor
# * pi
# * tau
# * e
# * inf
# * nan
